# %% [markdown]
# # AUTOMOBILE DATASET

# %%
import pandas as pd

# %%
auto=pd.read_csv('Automobile.csv')

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
#no null values: as the non null values matches with the total observations
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
# symboling              201 non-null int64
# normalized_losses      201 non-null int64
# make                   201 non-null object
# fuel_type              201 non-null object
# aspiration             201 non-null object
# number_of_doors        201 non-null object
# body_style             201 non-null object
# drive_wheels           201 non-null object
# engine_location        201 non-null object
# wheel_base             201 non-null float64
# length                 201 non-null float64
# width                  201 non-null float64
# height                 201 non-null float64
# curb_weight            201 non-null int64
# engine_type            201 non-null object
# number_of_cylinders    201 non-null object
# engine_size            201 non-null int64
# fuel_system            201 non-null object
# bore                   201 non-null float64
# ...

# %%
auto.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
# Now we want to grab certain columns in any order
#pass it using a list

auto[['make','fuel_type']].head()
# Out:
#           make fuel_type
# 0  alfa-romero       gas
# 1  alfa-romero       gas
# 2  alfa-romero       gas
# 3         audi       gas
# 4         audi       gas

# %%
#columns are series

type(auto['make'])
# Out:
# pandas.core.series.Series

# %%
#create new columns
#now create a seperate column for average milage

auto['dummy']=1
auto['avg_mpg']=(auto['city_mpg']+auto['highway_mpg'])/2
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    bore  stroke  compression_ratio  horsepower peak_rpm city_mpg  highway_mpg  \
# ...

# %%
#remove columns
auto.drop(['avg_mpg','dummy'],axis=1,inplace=True)
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
#add again those columns and use diff method to
#remove those columns
auto['dummy']=1
auto['avg_mpg']=(auto['city_mpg']+auto['highway_mpg'])/2

auto=auto.drop(['avg_mpg','dummy'],axis=1)
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
#removing a row
#checking for the row names

print(auto.index)
auto1=auto.drop([0,1],axis=0)
auto1.head()
# Out:
# RangeIndex(start=0, stop=201, step=1)
#    symboling  normalized_losses         make fuel_type aspiration  \
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
# 5          2                161         audi       gas        std
# 6          1                158         audi       gas        std
#
#   number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 2             two  hatchback          rwd           front        94.5  ...
# 3            four      sedan          fwd           front        99.8  ...
# 4            four      sedan          4wd           front        99.4  ...
# 5             two      sedan          fwd           front        99.8  ...
# 6            four      sedan          fwd           front       105.8  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
#locating a specific row, say row 5
#iloc means index location 
#loc means locating using index names

auto.iloc[5]
# Out:
# symboling                  2
# normalized_losses        161
# make                    audi
# fuel_type                gas
# aspiration               std
# number_of_doors          two
# body_style             sedan
# drive_wheels             fwd
# engine_location        front
# wheel_base              99.8
# length                 177.3
# width                   66.3
# height                  53.1
# curb_weight             2507
# engine_type              ohc
# number_of_cylinders     five
# engine_size              136
# fuel_system             mpfi
# bore                    3.19
# stroke                   3.4
# compression_ratio        8.5
# horsepower               110
# peak_rpm                5500
# city_mpg                  19
# highway_mpg               25
# price                  15250
# Name: 5, dtype: object

# %%
#locating a coordinate
#pass it using list

auto.loc[[5,6],['city_mpg','price']]
# Out:
#    city_mpg  price
# 5        19  15250
# 6        19  17710

# %%
auto.describe()
# Out:
#         symboling  normalized_losses  wheel_base      length       width  \
# count  201.000000         201.000000  201.000000  201.000000  201.000000
# mean     0.840796         125.189055   98.797015  174.200995   65.889055
# std      1.254802          33.572966    6.066366   12.322175    2.101471
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.800000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.500000   66.600000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  engine_size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.329701    3.261741
# std      2.447822   517.296727    41.546834    0.268166    0.317875
# ...

# %%
#lets select a part of the datframe and work with them

auto2=auto.loc[0:10,:]
auto2
# Out:
#     symboling  normalized_losses         make fuel_type aspiration  \
# 0           3                168  alfa-romero       gas        std
# 1           3                168  alfa-romero       gas        std
# 2           1                168  alfa-romero       gas        std
# 3           2                164         audi       gas        std
# 4           2                164         audi       gas        std
# 5           2                161         audi       gas        std
# 6           1                158         audi       gas        std
# 7           1                168         audi       gas        std
# 8           1                158         audi       gas      turbo
# 9           2                192          bmw       gas        std
# 10          0                192          bmw       gas        std
#
#    number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0              two  convertible          rwd           front        88.6  ...
# ...

# %%
#description of the column city milage
auto2.city_mpg.describe()
# Out:
# count    11.000000
# mean     20.272727
# std       2.284334
# min      17.000000
# 25%      19.000000
# 50%      19.000000
# 75%      22.000000
# max      24.000000
# Name: city_mpg, dtype: float64

# %%
#we see that min milage is 17 and max is 24,lets check for all the cars with milage>20
auto2.city_mpg>20
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# Name: city_mpg, dtype: bool

# %%
#get all the details of those selected cars
auto2[auto2.city_mpg>20]
# Out:
#     symboling  normalized_losses         make fuel_type aspiration  \
# 0           3                168  alfa-romero       gas        std
# 1           3                168  alfa-romero       gas        std
# 3           2                164         audi       gas        std
# 9           2                192          bmw       gas        std
# 10          0                192          bmw       gas        std
#
#    number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0              two  convertible          rwd           front        88.6  ...
# 1              two  convertible          rwd           front        88.6  ...
# 3             four        sedan          fwd           front        99.8  ...
# 9              two        sedan          rwd           front       101.2  ...
# 10            four        sedan          rwd           front       101.2  ...
#
#     engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
#getting only the makers of the car
auto2[auto2.city_mpg>20].make
# Out:
# 0     alfa-romero
# 1     alfa-romero
# 3            audi
# 9             bmw
# 10            bmw
# Name: make, dtype: object

# %%
#always remember to pass the column name with a list otherwise the name of the col wont display
auto2[auto2.city_mpg>20][['city_mpg']]
# Out:
#     city_mpg
# 0         21
# 1         21
# 3         24
# 9         23
# 10        23

# %%
#the makers and its milage
auto2[auto2.city_mpg>20][['make','city_mpg']]
# Out:
#            make  city_mpg
# 0   alfa-romero        21
# 1   alfa-romero        21
# 3          audi        24
# 9           bmw        23
# 10          bmw        23

# %%
#getting all those columns which we require
auto2[auto2.city_mpg>20][['make','city_mpg','engine_location','horsepower']]
# Out:
#            make  city_mpg engine_location  horsepower
# 0   alfa-romero        21           front         111
# 1   alfa-romero        21           front         111
# 3          audi        24           front         102
# 9           bmw        23           front         101
# 10          bmw        23           front         101

# %%
#generally cars with more hp have low milage, lets see their correlation
auto2[['city_mpg','horsepower']].corr()
# Out:
#             city_mpg  horsepower
# city_mpg    1.000000   -0.634139
# horsepower -0.634139    1.000000

# %%
#description of the horsepower column
auto2.horsepower.describe()
# Out:
# count     11.000000
# mean     115.000000
# std       16.774981
# min      101.000000
# 25%      106.000000
# 50%      110.000000
# 75%      113.000000
# max      154.000000
# Name: horsepower, dtype: float64

# %%
#getting the mean horsepower and mean city milage

print(auto2.city_mpg.mean(),'\n',auto2.horsepower.mean())
# Out:
# 20.272727272727273
#  115.0

# %%
#checking for cars with hp>115 and milage>20
#we want better milage as well as good power

auto[auto.horsepower>115][auto.city_mpg>20]
# Out:
# C:\Users\LILENDAR\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#      symboling  normalized_losses           make fuel_type aspiration  \
# 11           0                188            bmw       gas        std
# 12           0                188            bmw       gas        std
# 64          -1                 93  mercedes-benz    diesel      turbo
# 65          -1                 93  mercedes-benz    diesel      turbo
# 66           0                 93  mercedes-benz    diesel      turbo
# 67          -1                 93  mercedes-benz    diesel      turbo
# 77           3                153     mitsubishi       gas      turbo
# 84           1                125     mitsubishi       gas      turbo
# 85          -1                137     mitsubishi       gas        std
# 163          2                134         toyota       gas        std
# ...

# %%
#the above list are our required cars
#lets check their bodystyles and also count them

print(auto[auto.horsepower>115][auto.city_mpg>20][['body_style']],'\n')
auto[auto.horsepower>115][auto.city_mpg>20]['body_style'].value_counts()
# Out:
#       body_style
# 11         sedan
# 12         sedan
# 64         sedan
# 65         wagon
# 66       hardtop
# 67         sedan
# 77     hatchback
# 84         sedan
# 85         sedan
# 163      hardtop
# 164      hardtop
# 165    hatchback
# 166      hardtop
# 167    hatchback
# 168  convertible
# C:\Users\LILENDAR\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# C:\Users\LILENDAR\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# sedan          6
# hardtop        4
# hatchback      3
# wagon          1
# convertible    1
# Name: body_style, dtype: int64

# %%
#giving unique identity to each and every car
#check the shape first
auto2.shape
# Out:
# (11, 26)

# %%
index1='id1 id2 id3 id4 id5 id6 id7 id8 id9 id10 id11'.split()
index1
# Out:
# ['id1', 'id2', 'id3', 'id4', 'id5', 'id6', 'id7', 'id8', 'id9', 'id10', 'id11']

# %%
#create a column having this identities and then st them as index column
auto2['index']=index1
auto2.set_index('index',inplace=True)
# Out:
# C:\Users\LILENDAR\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
auto2.head()
# Out:
#        symboling  normalized_losses         make fuel_type aspiration  \
# index
# id1            3                168  alfa-romero       gas        std
# id2            3                168  alfa-romero       gas        std
# id3            1                168  alfa-romero       gas        std
# id4            2                164         audi       gas        std
# id5            2                164         audi       gas        std
#
#       number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# index
# id1               two  convertible          rwd           front        88.6
# id2               two  convertible          rwd           front        88.6
# id3               two    hatchback          rwd           front        94.5
# id4              four        sedan          fwd           front        99.8
# id5              four        sedan          4wd           front        99.4
#
#        ...  engine_size  fuel_system  bore  stroke compression_ratio  \
# ...
